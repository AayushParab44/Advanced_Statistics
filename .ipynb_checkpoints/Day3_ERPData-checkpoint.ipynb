# %%
import os

import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\AAYUSH\\Desktop\\Advanced Statistics'

# %%
os.chdir(r'C:\\Users\\AAYUSH\\Desktop')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\AAYUSH\\Desktop'

# %%
df=pd.read_excel(r'CDAC_DataBook.xlsx',sheet_name='ERPData')

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df['Status']=df['Quantity'].apply(lambda x: 'Scrap' if x<50 else ('Useful' if x<=100 else 'Very Useful'))

# %%
df
# Out:
#    MaterialID Location  Quantity       Status
# 0     TMI-43T    MWH-4        34        Scrap
# 1     AXCP-78    MWH-1        67       Useful
# 2     LXCV-21    MWH-2        27        Scrap
# 3     AXCP-78    MWH-5        65       Useful
# 4     AXCP-78    MWH-4        36        Scrap
# 5     TMI-43T    MWH-4        78       Useful
# 6     TMI-43T    MWH-4        31        Scrap
# 7     TMI-43T    MWH-2        29        Scrap
# 8     GCVB-79    MWH-2        10        Scrap
# 9     TMI-43T    MWH-1       120  Very Useful
# 10    SDRT-67    MWH-1        34        Scrap
# 11    SDRT-67    MWH-4        58       Useful
# 12    TMI-43T    MWH-4        76       Useful
# 13    TMI-43T    MWH-4        32        Scrap
# 14    TMI-43T    MWH-3        65       Useful
# 15    GCVB-79    MWH-2        87       Useful
# 16    SDRT-67    MWH-5        12        Scrap
# 17    SDRT-67    MWH-5       102  Very Useful
# 18    TMI-43T    MWH-4        34        Scrap
# 19    TMI-43T    MWH-4        52       Useful
# 20    TMI-43T    MWH-4        39        Scrap
# 21    TMI-43T    MWH-4        75       Useful
# 22    DDBN-89    MWH-4        48        Scrap
# 23    DDBN-89    MWH-5        71       Useful
# 24    AXCP-78    MWH-1       152  Very Useful
# 25    AXCP-78    MWH-1       109  Very Useful
# 26    DDBN-89    MWH-1        57       Useful
# 27    LXCV-21    MWH-5        83       Useful
# 28    LXCV-21    MWH-5        34        Scrap
# 29    LXCV-21    MWH-5        57       Useful
# 30    DDBN-89    MWH-4        27        Scrap
# 31    TMI-43T    MWH-4        65       Useful
# 32    TMI-43T    MWH-4        43        Scrap
# 33    TMI-43T    MWH-5       112  Very Useful
# 34    GCVB-79    MWH-5        26        Scrap
# 35    GCVB-79    MWH-2        31        Scrap
# 36    GCVB-79    MWH-2        28        Scrap
# 37    AXCP-78    MWH-5        65       Useful
# 38    AXCP-78    MWH-5        70       Useful
# 39    AXCP-78    MWH-1       145  Very Useful
# 40    DDBN-89    MWH-1        34        Scrap
# 41    SDRT-67    MWH-1        57       Useful
# 42    SDRT-67    MWH-2        31        Scrap
# 43    DDBN-89    MWH-3        38        Scrap
# 44    LXCV-21    MWH-3        42        Scrap
# 45    DDBN-89    MWH-2        69       Useful
# 46    AXCP-78    MWH-2        85       Useful
# 47    AXCP-78    MWH-3        29        Scrap
# 48    AXCP-78    MWH-1        75       Useful
# 49    DDBN-89    MWH-1        39        Scrap

# %%
# # status=useful,scracp

# <50->scrap
# >=50->useful

# %%
df[(df['Quantity']>70) & ((df['Location']=='MWH-2') | (df['Location']=='MWH-4'))]
# Out:
#    MaterialID Location  Quantity  Status
# 5     TMI-43T    MWH-4        78  Useful
# 12    TMI-43T    MWH-4        76  Useful
# 15    GCVB-79    MWH-2        87  Useful
# 21    TMI-43T    MWH-4        75  Useful
# 46    AXCP-78    MWH-2        85  Useful
